# %%
import pyodbc
import pandas as pd 
import os
from datetime import datetime
from plyer import notification
#create sql connection
import pyodbc

# Tạo chuỗi kết nối
server = r"NGOC-A-HOANG\NGUYENHOANG"
database = "Windturbine"
user = "windturbine"
password = "hoangga2001"

connection_string = "Driver={ODBC Driver 17 for SQL Server};" \
                    f"Server={server};" \
                    f"Database={database};" \
                    f"Uid={user};" \
                    f"Pwd={password};"

# Tạo kết nối
connection = pyodbc.connect(connection_string)

# print(pyodbc.drivers())
sqlQuery = "SELECT TOP(1000) *FROM dbo.data ORDER BY ID DESC "
df=pd.read_sql(sql=sqlQuery,con=connection)
df_reversed = df.sort_values(by="ID", ascending=True)
# connection.close()
df_reversed.head()
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_4156\694937546.py:26: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df=pd.read_sql(sql=sqlQuery,con=connection)
#          ID         PCTimeStamp  WTG01_Ambient WindSpeed Avg. (1)  \
# 999  102306 2023-09-24 01:20:00                              5.70
# 998  102307 2023-09-24 01:30:00                              5.80
# 997  102308 2023-09-24 01:40:00                              5.61
# 996  102309 2023-09-24 01:50:00                              5.66
# 995  102310 2023-09-24 02:00:00                              5.34
#
#      WTG02_Ambient WindSpeed Avg. (2)  WTG03_Ambient WindSpeed Avg. (3)  \
# 999                              6.32                              5.52
# 998                              6.29                              5.71
# 997                              6.17                              6.18
# 996                              6.15                              5.74
# 995                              5.67                              5.20
#
#      WTG04_Ambient WindSpeed Avg. (4)  WTG05_Ambient WindSpeed Avg. (5)  \
# 999                              5.89                              5.97
# 998                              6.00                              5.77
# 997                              5.77                              5.35
# 996                              5.62                              5.44
# 995                              5.28                              5.57
#
#      WTG06_Ambient WindSpeed Avg. (6)  WTG07_Ambient WindSpeed Avg. (7)  \
# 999                              5.73                              5.33
# 998                              5.23                              5.24
# 997                              5.36                              4.98
# 996                              5.76                              5.18
# 995                              5.38                              5.52
#
#      WTG01_Ambient WindDir Absolute Avg. (8)  ...  \
# 999                               203.641006  ...
# 998                               208.565002  ...
# 997                               204.787994  ...
# 996                               203.473007  ...
# 995                               203.389008  ...
#
#      WTG05_Ambient Temp. Avg. (19)  WTG06_Ambient Temp. Avg. (20)  \
# 999                             25                             25
# 998                             25                             25
# 997                             25                             25
# 996                             25                             25
# 995                             25                             25
#
#      WTG07_Ambient Temp. Avg. (21)  WTG01_Grid Production Power Avg. (22)  \
# 999                             25                             797.056030
# 998                             25                             809.088013
# 997                             25                             766.719971
# 996                             25                             776.575989
# 995                             25                             615.935974
#
#      WTG02_Grid Production Power Avg. (23)  \
# 999                            1017.728027
# 998                             967.359985
# 997                             867.520020
# 996                             897.791992
# 995                             629.504028
#
#      WTG03_Grid Production Power Avg. (24)  \
# 999                             764.223999
# 998                             823.616028
# 997                            1037.375977
# 996                             836.479980
# 995                             616.768005
#
#      WTG04_Grid Production Power Avg. (25)  \
# 999                             891.520020
# 998                             907.328003
# 997                             858.687988
# 996                             821.823975
# 995                             631.935974
#
#      WTG05_Grid Production Power Avg. (26)  \
# 999                             904.127991
# 998                             815.231995
# 997                             645.888000
# 996                             686.271973
# 995                             716.992004
#
#      WTG06_Grid Production Power Avg. (27)  \
# 999                             803.072021
# 998                             658.815979
# 997                             675.328003
# 996                             828.736023
# 995                             751.424011
#
#      WTG07_Grid Production Power Avg. (28)
# 999                             664.703979
# 998                             586.047974
# 997                             484.608002
# 996                             596.351990
# 995                             753.664001
#
# [5 rows x 30 columns]

# %%
import pandas as pd
df=pd.read_csv('notebook\data\data.csv')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# d:\DO_AN\Du_bao_cong_suat_turbine\windturbine2\notebook\data\SQL.ipynb Cell 2 line 1
# ----> <a href='vscode-notebook-cell:/d%3A/DO_AN/Du_bao_cong_suat_turbine/windturbine2/notebook/data/SQL.ipynb#W1sZmlsZQ%3D%3D?line=0'>1</a> import pandas as pd
#       <a href='vscode-notebook-cell:/d%3A/DO_AN/Du_bao_cong_suat_turbine/windturbine2/notebook/data/SQL.ipynb#W1sZmlsZQ%3D%3D?line=1'>2</a> df=pd.read_csv('notebook\data\data.csv')
#
# ModuleNotFoundError: No module named 'pandas'
